# %%
lista = []

# %%
lista
# Out:
# []

# %%
lista.append(32)

# %%
lista
# Out:
# [32]

# %%
len(lista)
# Out:
# 1

# %%
lista.append("IFPI")

# %%
lista
# Out:
# [32, 'IFPI']

# %%
type(lista)
# Out:
# list

# %%
lista[0]
# Out:
# 32

# %%
lista[len(lista)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 lista[len(lista)]
#
# IndexError: list index out of range

# %%
lista[len(lista)-1]
# Out:
# 'IFPI'

# %%
lista[-1]
# Out:
# 'IFPI'

# %%
lista[-2]
# Out:
# 32

# %%
lista[-3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 lista[-3]
#
# IndexError: list index out of range

# %%
posicao = 0
numero = 1
lista.insert(posicao, numero)
lista
# Out:
# [1, 32, 'IFPI']

# %%
lista.insert(100, numero)
lista
# Out:
# [1, 32, 'IFPI', 1]

# %%
lista.insert(10000, True)
lista
# Out:
# [1, 32, 'IFPI', 1, True]

# %%
lista[3]
# Out:
# 1

# %%
lista[3] = 3.1415
lista
# Out:
# [1, 32, 'IFPI', 3.1415, True]

# %%
32 in lista
# Out:
# True

# %%
False in lista
# Out:
# False
