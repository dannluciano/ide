# %%
texto = "Texto Bem Grande, Muito GrandeeeeEEEEEE!"

# %%
len(texto)
# Out:
# 40

# %%
texto[0]
# Out:
# 'T'

# %%
texto[len(texto)-1]
# Out:
# '!'

# %%
for indice in range(0, len(texto), 1):
    print(indice, texto[indice])
# Out:
# 0 T
# 1 e
# 2 x
# 3 t
# 4 o
# 5
# 6 B
# 7 e
# 8 m
# 9
# 10 G
# 11 r
# 12 a
# 13 n
# 14 d
# 15 e
# 16 ,
# 17
# 18 M
# 19 u
# 20 i
# 21 t
# 22 o
# 23
# 24 G
# 25 r
# 26 a
# 27 n
# 28 d
# 29 e
# 30 e
# 31 e
# 32 e
# 33 E
# 34 E
# 35 E
# 36 E
# 37 E
# 38 E
# 39 !

# %%
for caractere in texto:
    print(caractere)
# Out:
# T
# e
# x
# t
# o
#
# B
# e
# m
#
# G
# r
# a
# n
# d
# e
# ,
#
# M
# u
# i
# t
# o
#
# G
# r
# a
# n
# d
# e
# e
# e
# e
# E
# E
# E
# E
# E
# E
# !
